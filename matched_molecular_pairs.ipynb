# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahan08/RDKit-application-Cheminformatics-Analysis/blob/main/matched_molecular_pairs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Matched Molecular Pairs
# This notebook provides an example of the use of Matched Molecular Pairs, a technique described in
#
# Hussain, Jameed, and Ceara Rea. "Computationally efficient algorithm to identify matched molecular pairs (MMPs) in large data sets." *Journal of Chemical Information and Modeling*, **50** (2010): 339-348. https://doi.org/10.1021/ci900450m
#
# These papers provide good reviews of the method and its applications.
#
# Dossetter, Alexander G., Edward J. Griffen, and Andrew G. Leach. "Matched molecular pair analysis in drug discovery." *Drug Discovery Today*, **18** (2013): 724-731. https://doi.org/10.1016/j.drudis.2013.03.003
#
# Wassermann, A. M., Dimova, D., Iyer, P., & Bajorath, J., Advances in computational medicinal chemistry: matched molecular pair analysis. *Drug Development Research*, **73** (2012): 518-527. https://doi.org/10.1002/ddr.21045
#
# Tyrchan, Christian, and Emma Evertsson. "Matched molecular pair analysis in short: algorithms, applications and limitations," *Computational and Structural Biotechnology Journal* **15** (2017): 86-90. https://doi.org/10.1016/j.csbj.2016.12.003
#
# In this notebook we'll look at a hERG inhibition dataset from the ChEMBL database and examine the impact of specific chemical changes on hERG inhibition.

# %% [markdown]
# ### Setup
# Check to see if we're running Google Colab.

# %%
import sys
IN_COLAB = 'google.colab' in sys.modules

# %% [markdown]
# Install the necessary Python libraries

# %%
if IN_COLAB:
    # !pip install pandas requests rdkit useful_rdkit_utils mols2grid
    # need this to fix a Pandas bug
    # !pip install numexpr==2.8.4
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Collecting rdkit
#   Downloading rdkit-2024.3.5-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.9 kB)
# Collecting useful_rdkit_utils
#   Downloading useful_rdkit_utils-0.3.12-py3-none-any.whl.metadata (2.0 kB)
# Collecting mols2grid
#   Downloading mols2grid-2.0.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (10.4.0)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from useful_rdkit_utils) (16.1.0)
# Collecting pystow (from useful_rdkit_utils)
#   Downloading pystow-0.5.6-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: ipywidgets<8,>=7 in /usr/local/lib/python3.10/dist-packages (from mols2grid) (7.7.1)
# Requirement already satisfied: jinja2>=2.11.0 in /usr/local/lib/python3.10/dist-packages (from mols2grid) (3.1.4)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->mols2grid) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->mols2grid) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->mols2grid) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->mols2grid) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->mols2grid) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8,>=7->mols2grid) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.11.0->mols2grid) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from pystow->useful_rdkit_utils) (8.1.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pystow->useful_rdkit_utils) (4.66.5)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->mols2grid) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7->mols2grid) (6.3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (75.1.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (4.9.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.8.4)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.21.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8,>=7->mols2grid) (0.2.13)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (4.3.6)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.3.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (24.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (4.23.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.20.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.10/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.24.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (2.6)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (2.22)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8,>=7->mols2grid) (1.2.2)
# Downloading rdkit-2024.3.5-cp310-cp310-manylinux_2_28_x86_64.whl (33.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 46.5 MB/s eta 0:00:00
# Downloading useful_rdkit_utils-0.3.12-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 7.7 MB/s eta 0:00:00
# Downloading mols2grid-2.0.0-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 7.7 MB/s eta 0:00:00
# Downloading pystow-0.5.6-py3-none-any.whl (32 kB)
# Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 54.9 MB/s eta 0:00:00
# Installing collected packages: rdkit, jedi, pystow, useful_rdkit_utils, mols2grid
# Successfully installed jedi-0.19.1 mols2grid-2.0.0 pystow-0.5.6 rdkit-2024.3.5 useful_rdkit_utils-0.3.12
# Collecting numexpr==2.8.4
#   Downloading numexpr-2.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.0 kB)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from numexpr==2.8.4) (1.26.4)
# Downloading numexpr-2.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (381 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.4/381.4 kB 11.9 MB/s eta 0:00:00
# Installing collected packages: numexpr
#   Attempting uninstall: numexpr
#     Found existing installation: numexpr 2.10.1
#     Uninstalling numexpr-2.10.1:
#       Successfully uninstalled numexpr-2.10.1
# Successfully installed numexpr-2.8.4

# %% [markdown]
# Download the scaffold_finder library from GitHub.

# %%
if IN_COLAB:
    import requests
    lib_file = requests.get("https://raw.githubusercontent.com/PatWalters/practical_cheminformatics_tutorials/main/sar_analysis/scaffold_finder.py")
    ofs = open("scaffold_finder.py","w")
    print(lib_file.text,file=ofs)
    ofs.close()

# %% [markdown]
# Import the necessary Python libraries

# %%
import pandas as pd
from rdkit import Chem
from scaffold_finder import FragmentMol
from operator import itemgetter
from tqdm.auto import tqdm
import useful_rdkit_utils as uru
from itertools import combinations
import mols2grid
from rdkit.Chem import AllChem
from rdkit.Chem.Draw import ReactionToImage
import seaborn as sns
from tqdm.auto import tqdm
import numpy as np

from rdkit.Chem.Draw import rdMolDraw2D
import io
import base64
from IPython.display import HTML
import matplotlib.pyplot as plt

# %% [markdown]
# Enable progress bars in Pandas

# %%
tqdm.pandas()

# %% [markdown]
# ### Read and Process the Input Data
# Read in hERG data from ChEMBL.  The format is pretty simple, SMILES, ChEMBL ID, hERG pIC50 (negative log of the IC50).

# %%
df = pd.read_csv("https://raw.githubusercontent.com/PatWalters/practical_cheminformatics_tutorials/main/data/hERG.csv")

# %% [markdown]
# Some useful utility functions

# %%
def remove_map_nums(mol):
    """
    Remove atom map numbers from a molecule
    """
    for atm in mol.GetAtoms():
        atm.SetAtomMapNum(0)

def sort_fragments(mol):
    """
    Transform a molecule with multiple fragments into a list of molecules that is sorted by number of atoms
    from largest to smallest
    """
    frag_list = list(Chem.GetMolFrags(mol, asMols=True))
    [remove_map_nums(x) for x in frag_list]
    frag_num_atoms_list = [(x.GetNumAtoms(), x) for x in frag_list]
    frag_num_atoms_list.sort(key=itemgetter(0), reverse=True)
    return [x[1] for x in frag_num_atoms_list]

# %% [markdown]
# Add an RDKit molecule column to the dataframe

# %%
df['mol'] = df.SMILES.apply(Chem.MolFromSmiles)

# %% [markdown]
# Remove salts, counterions, etc.

# %%
df.mol = df.mol.apply(uru.get_largest_fragment)

# %% [markdown]
# ### Decompose Molecules to Scaffolds and Sidechains
# Convert molecules to scaffold/sidechain pairs

# %%
row_list = []
for smiles, name, pIC50, mol in tqdm(df.values):
    frag_list = FragmentMol(mol,maxCuts=1)
    for _,frag_mol in frag_list:
        pair_list = sort_fragments(frag_mol)
        tmp_list = [smiles]+[Chem.MolToSmiles(x) for x in pair_list]+[name, pIC50]
        row_list.append(tmp_list)
row_df = pd.DataFrame(row_list,columns=["SMILES","Core","R_group","Name","pIC50"])
row_df.head(4)
# Out:
#   0%|          | 0/4042 [00:00<?, ?it/s]
#                                               SMILES  \
# 0  O=C1NCCN1CCN1CCC(c2cn(-c3ccc(F)cc3)c3ccc(Cl)cc...
# 1  O=C1NCCN1CCN1CCC(c2cn(-c3ccc(F)cc3)c3ccc(Cl)cc...
# 2  O=C1NCCN1CCN1CCC(c2cn(-c3ccc(F)cc3)c3ccc(Cl)cc...
# 3  O=C1NCCN1CCN1CCC(c2cn(-c3ccc(F)cc3)c3ccc(Cl)cc...
#
#                                            Core                 R_group  \
# 0  *CCN1CCC(c2cn(-c3ccc(F)cc3)c3ccc(Cl)cc23)CC1              *N1CCNC1=O
# 1   *CN1CCC(c2cn(-c3ccc(F)cc3)c3ccc(Cl)cc23)CC1             *CN1CCNC1=O
# 2    *N1CCC(c2cn(-c3ccc(F)cc3)c3ccc(Cl)cc23)CC1            *CCN1CCNC1=O
# 3              *c1cn(-c2ccc(F)cc2)c2ccc(Cl)cc12  *C1CCN(CCN2CCNC2=O)CC1
#
#           Name  pIC50
# 0  CHEMBL12713  8.025
# 1  CHEMBL12713  8.025
# 2  CHEMBL12713  8.025
# 3  CHEMBL12713  8.025

# %% [markdown]
# ### Collect Pairs With the Same Scaffold
# Find pairs of molecules sharing same scaffold (Core) and create a table containg pairs and the difference in pIC50 (Delta column). Add a transform column to the table containing the pair as a reaction transform (Transform column)(shows which R-group's performance better based on pIC50 values). Note that the SMILES are sorted before being put into the transform.  This provides a canonical ordering.

# %%
delta_list = []
for k,v in tqdm(row_df.groupby("Core")):
    if len(v) > 2:
        for a,b in combinations(range(0,len(v)),2):
            reagent_a = v.iloc[a]
            reagent_b = v.iloc[b]
            if reagent_a.SMILES == reagent_b.SMILES:
                continue
            reagent_a, reagent_b = sorted([reagent_a, reagent_b], key=lambda x: x.SMILES)
            delta=reagent_b.pIC50-reagent_a.pIC50
            delta_list.append(list(reagent_a.values)+list(reagent_b.values)
                              +[f"{reagent_a.R_group.replace('*','*-')}>>{reagent_b.R_group.replace('*','*-')}",delta])
# Out:
#   0%|          | 0/23636 [00:00<?, ?it/s]

# %% [markdown]
# Put the pairs into a dataframe.

# %%
cols = ["SMILES_1","Core_1","R_group_1","Name_1","pIC50_1",
       "SMILES_2","Core_2","Rgroup_1","Name_2","pIC50_2",
       "Transform","Delta"]
delta_df = pd.DataFrame(delta_list,columns=cols)
delta_df.head(3)
# Out:
#                        SMILES_1          Core_1         R_group_1  \
# 0  CCCCN(CC)CC#CC#Cc1ccc(Cl)cc1  *C#CCN(CC)CCCC  *C#Cc1ccc(Cl)cc1
# 1  CCCCN(CC)CC#CCOCc1ccc(Cl)cc1  *C#CCN(CC)CCCC  *COCc1ccc(Cl)cc1
# 2    CCCCN(CC)CC#CCCc1ccc(C)cc1  *C#CCN(CC)CCCC    *CCc1ccc(C)cc1
#
#           Name_1  pIC50_1                      SMILES_2          Core_2  \
# 0  CHEMBL3093979    5.665  CCCCN(CC)CC#CCOCc1ccc(Cl)cc1  *C#CCN(CC)CCCC
# 1  CHEMBL3093951    5.130   CCCCN(CC)CC#CCOc1ccc(Cl)cc1  *C#CCN(CC)CCCC
# 2  CHEMBL3093977    5.250  CCCCN(CC)CC#CCOCc1ccc(Cl)cc1  *C#CCN(CC)CCCC
#
#            Rgroup_1         Name_2  pIC50_2  \
# 0  *COCc1ccc(Cl)cc1  CHEMBL3093951     5.13
# 1   *COc1ccc(Cl)cc1  CHEMBL3093981     4.84
# 2  *COCc1ccc(Cl)cc1  CHEMBL3093951     5.13
#
#                               Transform  Delta
# 0  *-C#Cc1ccc(Cl)cc1>>*-COCc1ccc(Cl)cc1 -0.535
# 1   *-COCc1ccc(Cl)cc1>>*-COc1ccc(Cl)cc1 -0.290
# 2    *-CCc1ccc(C)cc1>>*-COCc1ccc(Cl)cc1 -0.120

# %% [markdown]
# ### Collect Frequently Occuring Pairs
# Summarize reaction transforms that occur more than **min_transform_occurrence** times. Collect the deltas and calculate and store their mean.  Create a reaction molecule (rxn_mol) for display.

# %%
min_transform_occurrence = 5
mmp_list = []
for k,v in delta_df.groupby("Transform"):
    if len(v) > min_transform_occurrence:
        mmp_list.append([k,len(v),v.Delta.values])
mmp_df = pd.DataFrame(mmp_list,columns=["Transform","Count","Deltas"])
mmp_df['idx'] = range(0,len(mmp_df))
mmp_df['mean_delta'] = [x.mean() for x in mmp_df.Deltas]
mmp_df['rxn_mol'] = mmp_df.Transform.apply(AllChem.ReactionFromSmarts,useSmiles=True)

# %% [markdown]
# Sort **mmp_df** to find the most interesting pairs.

# %%
mmp_df.sort_values("mean_delta")
# Out:
#                        Transform  Count  \
# 41  *-Cc1ccc(Cl)cc1>>*-Cc1ccccc1      8
# 78     *-c1ccc(F)cc1>>*-c1cccnc1      6
# 77     *-c1ccc(F)cc1>>*-c1ccccn1      8
# 72    *-c1ccc(Cl)cc1>>*-c1ccccc1     17
# 87    *-c1cccc(Cl)c1>>*-c1ccccc1      7
# ..                           ...    ...
# 34              *-CC>>*-c1ccccc1      8
# 51                   *-OC>>*-C#N     13
# 6             *-C#N>>*-OC(F)(F)F      6
# 56             *-OC>>*-OC(F)(F)F     10
# 92      *-c1ccccc1>>*-c1ccccc1Cl      6
#
#                                                Deltas  idx  mean_delta  \
# 41  [-0.46999999999999975, -1.7349999999999994, -1...   41   -1.104375
# 78  [-0.7600000000000007, -1.1599999999999993, -1....   78   -0.913333
# 77  [0.0, -0.5500000000000007, -1.2199999999999998...   77   -0.722292
# 72  [0.1200000000000001, -0.5599999999999996, -0.4...   72   -0.641863
# 87  [0.009999999999999787, -0.26666666666999994, -...   87   -0.615238
# ..                                                ...  ...         ...
# 34  [0.6099999999999994, 0.39000000000000057, 1.01...   34    0.565000
# 51  [0.0600000000000005, 0.2999999999999998, 0.200...   51    0.591923
# 6   [0.5999999999999996, 0.6999999999999993, 0.660...    6    0.643333
# 56  [1.1600000000000001, -0.27000000000000046, 0.8...   56    0.653000
# 92  [0.10000000000000053, 0.8600000000000003, 1.10...   92    0.708333
#
#                                               rxn_mol
# 41  <rdkit.Chem.rdChemReactions.ChemicalReaction o...
# 78  <rdkit.Chem.rdChemReactions.ChemicalReaction o...
# 77  <rdkit.Chem.rdChemReactions.ChemicalReaction o...
# 72  <rdkit.Chem.rdChemReactions.ChemicalReaction o...
# 87  <rdkit.Chem.rdChemReactions.ChemicalReaction o...
# ..                                                ...
# 34  <rdkit.Chem.rdChemReactions.ChemicalReaction o...
# 51  <rdkit.Chem.rdChemReactions.ChemicalReaction o...
# 6   <rdkit.Chem.rdChemReactions.ChemicalReaction o...
# 56  <rdkit.Chem.rdChemReactions.ChemicalReaction o...
# 92  <rdkit.Chem.rdChemReactions.ChemicalReaction o...
#
# [103 rows x 6 columns]

# %% [markdown]
# To make life simpler, create an index that links the two dataframes **mmp_df** and **delta_df**

# %%
# Create a dictionary that links the SMILES for an MMP to its index value
transform_dict = dict([(a,b) for a,b in mmp_df[["Transform","idx"]].values])
# Add the index column to delta_df
delta_df['idx'] = [transform_dict.get(x) for x in delta_df.Transform]

# %% [markdown]
# ### Visualize the Results

# %% [markdown]
# Visualize one of the transforms

# %%
current_idx = 33
mmp_df.rxn_mol.values[current_idx]

# %% [markdown]
# Plot the distribution of deltas as a [stripplot](https://seaborn.pydata.org/generated/seaborn.stripplot.html).

# %%
sns.set(rc={'figure.figsize': (3, 1)})
sns.set_style('whitegrid')
ax = sns.stripplot(x=mmp_df.Deltas.values[current_idx])
ax.axvline(0,ls="--",c="red")
ax.set_xlim(-5,5);

# %% [markdown]
# We want to create a table showing MMP transforms, and the associated distributions of activity differences (Deltas).  To create this table we need to have routines that will generate images and save them as base64 encoded strings that can be displayed in an HTML table. A lot of tricks here were borrowed from an "Is Life Worth Living" blog [post](https://iwatobipen.wordpress.com/2020/01/17/draw-rdkit-mol-reaction-object-on-html-without-static-png-image-rdkit-memo/).  Thanks Pen!

# %%
def rxn_to_base64_image(rxn):
    """
    Convert an RDKit reaction to an image
    """
    drawer = rdMolDraw2D.MolDraw2DCairo(300, 150)
    drawer.DrawReaction(rxn)
    drawer.FinishDrawing()
    bio = io.BytesIO()
    text = drawer.GetDrawingText()
    im_text64 = base64.b64encode(text).decode('utf8')
    img_str = f"<img src='...{im_text64}'/>"
    return img_str

def strippplot_base64_image(dist):
    """
    Plot a distribution as a seaborn stripplot and save the resulting image as a base64 image.
    """
    sns.set(rc={'figure.figsize': (3, 1)})
    sns.set_style('whitegrid')
    ax = sns.stripplot(x=dist)
    ax.axvline(0,ls="--",c="red")
    ax.set_xlim(-5,5)
    s = io.BytesIO()
    plt.savefig(s, format='png', bbox_inches="tight")
    plt.close()
    s = base64.b64encode(s.getvalue()).decode("utf-8").replace("\n", "")
    return '<img align="left" src="data:image/png;base64,%s">' % s

# %% [markdown]
# Generate images to go into the HTML table and add them to **mmp_df**.

# %%
mmp_df['MMP Transform'] = mmp_df.rxn_mol.progress_apply(rxn_to_base64_image)
mmp_df['Delta Distribution'] = mmp_df.Deltas.progress_apply(strippplot_base64_image)
# Out:
#   0%|          | 0/103 [00:00<?, ?it/s]
#   0%|          | 0/103 [00:00<?, ?it/s]

# %% [markdown]
# Show a table of MMPs with associated activity distributions. Change **rows_to_show** below to change the number of rows show in the table.  The variable **ascending** in the table below controls the sort order for the table.  If **ascending** is set to **True**, MMPs that reduce the hERG IC50 are shown at the top of the table. If we set **ascending** to **False**, MMPs that increase hERG activity will be shown at the top. The table shows
# - the MMP
# - the number of times the MMP occurs in the dataset
# - the mean of the difference in pIC50 between molecules containing that MMP
# - a stripplot showing the differences
#
# If we look at the first row in the table (index 41 in the far left column), we see that when chlorobenzyl is replaced by benzyl the hERG IC50 is consistently reduced.  If we havea molecule with a chlorobenzyl group that has hERG activity, we might think aobut replacing the chlorobenzyl with benzyl.

# %%
rows_to_show = 10
ascending = True
mmp_df.sort_values("mean_delta",inplace=True,ascending=ascending)
HTML(mmp_df[['MMP Transform','Count',"mean_delta","Delta Distribution"]].round(2).head(rows_to_show).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>MMP Transform</th>
#       <th>Count</th>
#       <th>mean_delta</th>
#       <th>Delta Distribution</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>41</th>
#       <td><img src='......'/></td>
#       <td>8</td>
#       <td>-1.10</td>
#       <td><img align="left" src="data:image/png;base64,..."></td>
#     </tr>
#     <tr>
#       <th>78</th>
#       <td><img src='......'/></td>
#       <td>6</td>
#       <td>-0.91</td>
#       <td><img align="left" src="data:image/png;base64,..."></td>
#     </tr>
#     <tr>
#       <th>77</th>
#       <td><img src='......'/></td>
#       <td>8</td>
#       <td>-0.72</td>
#       <td><img align="left" src="data:image/png;base64,..."></td>
#     </tr>
#     <tr>
#       <th>72</th>
#       <td><img src='......'/></td>
#       <td>17</td>
#       <td>-0.64</td>
#       <td><img align="left" src="data:image/png;base64,..."></td>
#     </tr>
#     <tr>
#       <th>87</th>
#       <td><img src='......'/></td>
#       <td>7</td>
#       <td>-0.62</td>
#       <td><img align="left" src="data:image/png;base64,..."></td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td><img src='......'/></td>
#       <td>6</td>
#       <td>-0.51</td>
#       <td><img align="left" src="data:image/png;base64,..."></td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td><img src='......'/></td>
#       <td>8</td>
#       <td>-0.51</td>
#       <td><img align="left" src="data:image/png;base64,..."></td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td><img src='......'/></td>
#       <td>10</td>
#       <td>-0.50</td>
#       <td><img align="left" src="data:image/png;base64,..."></td>
#     </tr>
#     <tr>
#       <th>84</th>
#       <td><img src='......'/></td>
#       <td>9</td>
#       <td>-0.48</td>
#       <td><img align="left" src="data:image/png;base64,..."></td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td><img src='......'/></td>
#       <td>7</td>
#       <td>-0.48</td>
#       <td><img align="left" src="data:image/png;base64,..."></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Once we scan the table above and identify an interesting MMP, we may want to look at all the molecules containing that MMP.  To do that, we need need to go into **delta_df** and find the corresponding rows.  To make it easy to view the examples with mols2grid, we'll put the MMPs in alternating rows in a new talble.  The function below creates a new table with all the rows in **delta_df** having the the value **query_idx** in the **idx** column. The value we use for **query_idx** is the number in the far left column in the table above.

# %%
def find_examples(delta_df, query_idx):
    example_list = []
    for idx,row in delta_df.query("idx == @query_idx").sort_values("Delta",ascending=False).iterrows():
        smi_1, name_1, pIC50_1 = row.SMILES_1, row.Name_1, row.pIC50_1
        smi_2, name_2, pIC50_2 = row.SMILES_2, row.Name_2, row.pIC50_2
        tmp_list = [(smi_1, name_1, pIC50_1),(smi_2, name_2, pIC50_2)]
        tmp_list.sort(key=itemgetter(0))
        example_list.append(tmp_list[0])
        example_list.append(tmp_list[1])
    example_df = pd.DataFrame(example_list,columns=["SMILES","Name","pIC50"])
    return example_df

# %% [markdown]
# Show molecules that include a particular MMP transform. Change the value of **query_idx** to view molecules containing a particular MMP. Recall that **query_idx** is the far left column in the fancy table above showing the MMPs.

# %%
query_idx = 84
example_df = find_examples(delta_df, query_idx)
mols2grid.display(example_df,n_cols=4,template='static',prerender=True,size=(200,200),
                 subset=["img","pIC50","Name"],
                 transform={"pIC50": lambda x: f"{x:.2f}"})
# Out:
# MolGridWidget()
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: break-word;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: visible;
#     white-space: normal;
#     text-overflow: clip;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             /* Note: #mols2grid is the table element */
# #mols2grid {
#     border-collapse: collapse;
#     border-spacing: 0px;
#     /* Compensate for gap so table stays aligned with content above */
#     margin: 0px;
# }
# #mols2grid, tr, td {
#     border: none;
# }
# #mols2grid tr {
#     page-break-inside: avoid !important;
# }
#
# /* Cell */
# #mols2grid td {
#     border: 1px solid #cccccc;
#     text-align: center;
#     vertical-align: top;
#     max-width: 200px;
#     width: 200px;
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: 12px;
#     margin: 0;
#     padding: 10px;
#     position: relative;
# }
#
# /* Call focus state */
# #mols2grid td:focus-within,
# #mols2grid td:focus {
#     outline: solid 2px #555;
#     border-color: transparent;
# }
#
# /* ID */
# #mols2grid .data-mols2grid-id {
#     position: absolute;
#     top: 0;
#     left: 0;
#     padding: 5px;
# }
#
# /* Tooltip margin */
# /* Adjusted so it plays well with the extruded outline */
# .popover[x-placement] {
#     margin: 1px 2px 2px 1px;
# }
#
#
# #mols2grid td div img {
#     max-width: px;
#     width: px;
#     height: auto;
#     padding: 0;
# }
#
#             /* Custom CSS */
#
#         &lt;/style&gt;
#         &lt;script src=&quot;https://code.jquery.com/jquery-3.5.1.slim.min.js&quot; integrity=&quot;sha384-DfXdz2htPH0lsSSs5nCTpuj/zy4C+OGpamoFVy38MVBnE+IbbVYUew+OrCXaRkfj&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#         &lt;script&gt;
#     // Set iframe height to fit content.
#     function fitIframe(iframe) {
#         // Ignore when there&#x27;s no iframe
#         if (!iframe) return
#
#         // Only fit height when no specific height was given.
#         if (iframe.getAttribute(&#x27;height&#x27;)) return;
#
#         // Initial fit + refit whenever the window width changes.
#         _fit()
#         $(window).on(&#x27;resize&#x27;, function() {
#             if (window.innerWidth != window.prevInnerWidth) {
#                 window.prevInnerWidth = window.innerWidth
#                 _fit();
#             }
#         })
#
#         // Fit iframe height to content height.
#         function _fit() {
#             var height = iframe.contentDocument.body.scrollHeight + 18 + &#x27;px&#x27;;
#             iframe.style.height = height;
#         }
#     }
# &lt;/script&gt;
#
# &lt;!-- prettier-ignore --&gt;
# &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@4.6.0/dist/js/bootstrap.bundle.min.js&quot; integrity=&quot;sha384-Piv4xVNRyMGpqkS2by6br4gNJ7DXjqk09RmUpJ8jgGtD7zP9yug3goQfGII0yAns&quot; crossorigin=&quot;anonymous&quot;&gt;&lt;/script&gt;
#
#         &lt;!-- Custom header --&gt;
#
#
#
#
#
#     &lt;/head&gt;
#     &lt;body class=&quot;m2g-inside-iframe&quot;&gt;
#
#
#         &lt;table id=&quot;mols2grid&quot;&gt;
#             &lt;tbody&gt;
#                 &lt;tr class=&quot;row-0&quot;&gt;
# &lt;td class=&quot;col-0 m2g-tooltip&quot; tabindex=&quot;0&quot; data-toggle=&quot;popover&quot; data-content=&quot;&quot;&gt;
# &lt;div class=&quot;m2g-cell-0&quot;&gt;
# &lt;div class=&quot;data copy-me data-img&quot;&gt;&lt;?xml version=&#x27;1.0&#x27; encoding=&#x27;iso-8859-1&#x27;?&gt;
# &lt;svg version=&#x27;1.1&#x27; baseProfile=&#x27;full&#x27;
#               xmlns=&#x27;http://www.w3.org/2000/svg&#x27;
#                       xmlns:rdkit=&#x27;http://www.rdkit.org/xml&#x27;
#                       xmlns:xlink=&#x27;http://www.w3.org/1999/xlink&#x27;
#                   xml:space=&#x27;preserve&#x27;
# width=&#x27;200px&#x27; height=&#x27;200px&#x27; viewBox=&#x27;0 0 200 200&#x27;&gt;
# &lt;!-- END OF HEADER --&gt;
# &lt;rect style=&#x27;opacity:1.0;fill:#FFFFFF;stroke:none&#x27; width=&#x27;200.0&#x27; height=&#x27;200.0&#x27; x=&#x27;0.0&#x27; y=&#x27;0.0&#x27;&gt; &lt;/rect&gt;
# &lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 187.2,67.3 L 187.2,72.6&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;
# &lt;path class=&#x27;bond-0 atom-0 atom-1&#x27; d=&#x27;M 187.2,72.6 L 187.2,77.9&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#FF0000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;
# &lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 184.0,83.3 L 179.5,85.9&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#FF0000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;
# &lt;path class=&#x27;bond-1 atom-1 atom-2&#x27; d=&#x27;M 179.5,85.9 L 175.0,88.5&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;
# &lt;path class=&#x27;bond-2 atom-2 atom-3&#x27; d=&#x27;M 175.0,88.5 L 162.7,81.4&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;
# &lt;path class=&#x27;bond-2 atom-2 atom-3&#x27; d=&#x27;M 172.8,89.8 L 162.7,83.9&#x27; style=&#x27;fill:none;fill-rule:evenodd;stroke:#000000;stroke-width:2.0px;stroke-linecap:butt;stroke-linejoin:miter;stroke-opacity:1&#x27; /&gt;
# &lt;path class=&#x27;bond-3 atom-3 atom-4&#x27; d=&#x27;M 162.7,81.4 L 150.4,88.5&#
