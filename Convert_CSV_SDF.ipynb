# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahan08/RDKit-application/blob/main/Convert_CSV_SDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import glob
import os
import pandas as pd
df = pd.concat(map(pd.read_csv, glob.glob(os.path.join('', "*.csv"))))

# %%
df.to_csv('combined_data_Pancreatic_Cancer_Train.csv', index=False)

# %%
# !pip install rdkit
# Out:
# Requirement already satisfied: rdkit in /usr/local/lib/python3.10/dist-packages (2023.9.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.25.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (9.4.0)

# %%
import pandas as pd

import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import PandasTools

print(rdkit.rdBase.rdkitVersion)
# Out:
# 2023.09.5

# %%
traindata = pd.read_csv('/content/combined_data_Breast_Cancer.csv')
traindata.head()
# Out:
#                                               Smiles            ID  \
# 0        CC1(C)C=Cc2c(cc3c4c(nn3CCO)-c3ccccc3Oc24)O1   CHEMBL90334
# 1  CSCC[C@H](NC(=O)[C@H](Cc1ccc(O)c(C)c1C)NC(=O)[...  CHEMBL426843
# 2             CO[C@H]1N(OC)c2ccccc2[C@@]12CN=C(SC)S2  CHEMBL466266
# 3            CO[C@@H]1N(OC)c2ccccc2[C@@]12CN=C(SC)S2  CHEMBL466267
# 4            CN[C@@H]1N(OC)c2ccccc2[C@@]12CN=C(SC)S2  CHEMBL466073
#
#    standard_value  IC50_uM Activity  pIC50  BRC
# 0        100000.0    100.0       No    4.0    0
# 1        100000.0    100.0       No    4.0    0
# 2        100000.0    100.0       No    4.0    0
# 3        100000.0    100.0       No    4.0    0
# 4        100000.0    100.0       No    4.0    0

# %%
traindata['Smiles'].dtype
# Out:
# dtype('O')

# %%
traindata['Smiles'] = traindata['Smiles'].astype(str)

# %%
PandasTools.AddMoleculeColumnToFrame(frame=traindata, smilesCol='Smiles', molCol='Molecule')
problematicSmiles = traindata.loc[traindata['Molecule'].map(lambda x: x is None)]
problematicSmiles
# Out:
# [20:18:30] SMILES Parse Error: syntax error while parsing: nan
# [20:18:30] SMILES Parse Error: Failed parsing SMILES 'nan' for input: 'nan'
# [20:18:30] SMILES Parse Error: syntax error while parsing: nan
# [20:18:30] SMILES Parse Error: Failed parsing SMILES 'nan' for input: 'nan'
# [20:18:30] SMILES Parse Error: syntax error while parsing: nan
# [20:18:30] SMILES Parse Error: Failed parsing SMILES 'nan' for input: 'nan'
# [20:18:30] SMILES Parse Error: syntax error while parsing: nan
# [20:18:30] SMILES Parse Error: Failed parsing SMILES 'nan' for input: 'nan'
# [20:18:30] SMILES Parse Error: syntax error while parsing: nan
# [20:18:30] SMILES Parse Error: Failed parsing SMILES 'nan' for input: 'nan'
# [20:18:31] SMILES Parse Error: syntax error while parsing: nan
# [20:18:31] SMILES Parse Error: Failed parsing SMILES 'nan' for input: 'nan'
# [20:18:31] SMILES Parse Error: syntax error while parsing: nan
# [20:18:31] SMILES Parse Error: Failed parsing SMILES 'nan' for input: 'nan'
# [20:18:31] SMILES Parse Error: syntax error while parsing: nan
# [20:18:31] SMILES Parse Error: Failed parsing SMILES 'nan' for input: 'nan'
# [20:18:31] SMILES Parse Error: syntax error while parsing: nan
# [20:18:31] SMILES Parse Error: Failed parsing SMILES 'nan' for input: 'nan'
# [20:18:31] SMILES Parse Error: syntax error while parsing: nan
# [20:18:31] SMILES Parse Error: Failed parsing SMILES 'nan' for input: 'nan'
# [20:18:31] SMILES Parse Error: syntax error while parsing: nan
# [20:18:31] SMILES Parse Error: Failed parsing SMILES 'nan' for input: 'nan'
#      Smiles             ID  standard_value  IC50_uM Activity     pIC50  BRC  \
# 94      nan  CHEMBL2068447         94450.0    94.45       No  4.024798    0
# 619     nan    CHEMBL11359         65740.0    65.74       No  4.182170    0
# 655     nan  CHEMBL2068551         63800.0    63.80       No  4.195179    0
# 689     nan  CHEMBL2068288         62530.0    62.53       No  4.203912    0
# 1114    nan  CHEMBL2068563         49430.0    49.43       No  4.306009    0
# 1833    nan  CHEMBL2068449         36530.0    36.53       No  4.437350    0
# 2171    nan  CHEMBL2068304         32000.0    32.00       No  4.494850    0
# 2444    nan  CHEMBL2068444         29000.0    29.00       No  4.537602    0
# 2445    nan  CHEMBL2068561         29000.0    29.00       No  4.537602    0
# 3144    nan  CHEMBL2068292         23000.0    23.00       No  4.638272    0
# 3430    nan  CHEMBL2068295         21000.0    21.00       No  4.677781    0
#
#      Molecule
# 94       None
# 619      None
# 655      None
# 689      None
# 1114     None
# 1833     None
# 2171     None
# 2444     None
# 2445     None
# 3144     None
# 3430     None

# %%
problematicSmiles.to_csv('smiles.csv')

# %%
world_drugs = pd.read_csv('/content/combined_data_Colon_Cancer_Train.csv')

# %%
world_drugs.head(2)
# Out:
#                                               Smiles             ID  \
# 0  CC(C)NC(=N)c1ccc2nc(-c3ccc(Oc4ccnc5cc(Cl)ccc45...  CHEMBL4167105
# 1    CC(C)NC(=N)c1ccc2nc(N3Cc4ccccc4C3=O)[nH]c2c1.Cl  CHEMBL4225107
#
#    standard_value  IC50_uM Activity     pIC50  CLC
# 0         53300.0    53.30       No  4.273273    0
# 1         70970.0    70.97       No  4.148925    0

# %%
import pandas as pd
from rdkit.Chem import PandasTools
PandasTools.AddMoleculeColumnToFrame(world_drugs,'Smiles','Molecule') # pp = doesn't work for me
PandasTools.WriteSDF(world_drugs, 'combined_data_Colon_Cancer_Train.sdf', molColName='Molecule', properties=list(world_drugs.columns))

# %%
world_drugs1 = pd.read_csv('/content/combined_data_Test.csv')

# %%
import pandas as pd
from rdkit.Chem import PandasTools
PandasTools.AddMoleculeColumnToFrame(world_drugs1,'Smiles','Molecule') # pp = doesn't work for me
PandasTools.WriteSDF(world_drugs1, 'Combined_data_Test.sdf', molColName='Molecule', properties=list(world_drugs.columns))

# %%
world_drugs2 = pd.read_csv('/content/combined_data_Train.csv')

# %%
import pandas as pd
from rdkit.Chem import PandasTools
PandasTools.AddMoleculeColumnToFrame(world_drugs2,'Smiles','Molecule') # pp = doesn't work for me
PandasTools.WriteSDF(world_drugs2, 'Combined_data_Train.sdf', molColName='Molecule', properties=list(world_drugs.columns))
