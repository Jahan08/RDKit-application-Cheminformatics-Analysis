# %% [markdown]
# <a href="https://colab.research.google.com/github/Jahan08/RDKit-application/blob/main/Convert_CSV_SDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rdkit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 38.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import PandasTools

print(rdkit.rdBase.rdkitVersion)
# Out:
# 2023.03.3

# %%
world_drugs = pd.read_csv('/content/ChemDiv_HITS_150K.csv')

# %%
world_drugs1 = pd.read_csv('/content/Enamine_HITS_150K.csv')

# %%
print(len(world_drugs))

world_drugs = world_drugs.sample(10)

print(len(world_drugs))
# Out:
# 159
# 10

# %%
world_drugs.head(2)
# Out:
#       ID                                             Smiles
# 107  108             N1(CC2)C(CN2C(CCC#C)=O)=NN(CC3CC3)C1=O
# 100  101  C1(=O)[C@H](OC)[C@@H](N1C(C)C)C(CC2)CCN2C(=O)c...

# %%
import pandas as pd
from rdkit.Chem import PandasTools
PandasTools.AddMoleculeColumnToFrame(world_drugs,'Smiles','Molecule') # pp = doesn't work for me
PandasTools.WriteSDF(world_drugs, 'ChemDiv-HIF2a.sdf', molColName='Molecule', properties=list(world_drugs.columns))

# %%
world_drugs1.head(2)
# Out:
#     CatalogID                      Smiles
# 0   Z57481220    OC(c1ccc(Cn2cccc2)cc1)=O
# 1  Z732745046  Cn1ncc(c2ccc(C(O)=O)cc2)c1

# %%
import pandas as pd
from rdkit.Chem import PandasTools
PandasTools.AddMoleculeColumnToFrame(world_drugs1,'Smiles','Molecule') # pp = doesn't work for me
PandasTools.WriteSDF(world_drugs1, 'Enamine-HIF2a.sdf', molColName='Molecule', properties=list(world_drugs1.columns))
